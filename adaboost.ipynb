# %%
# Mount my Google Drive to get the data
from google.colab import drive
drive.mount('/content/drive')

import zipfile
import os
import pandas as pd
import numpy as np
import math
import tensorflow as tf
# Out:
# Mounted at /content/drive

# %%
# Unzips the file and extracts data
#!unzip '/content/drive/MyDrive/University of Toronto Elec & Comp Eng/Capstone/card_transaction.v1.zip' -d '/content/drive/MyDrive/University of Toronto Elec & Comp Eng/Capstone/card_transaction_dataset'

# %%
# Read and load the csv file
df = pd.read_csv('/content/drive/MyDrive/University of Toronto Elec & Comp Eng/Capstone/card_transaction_dataset/card_transaction.v1.csv')
df = df[0:16500000]
print(df)
# Out:
#           User  Card  Year  Month  Day   Time   Amount            Use Chip  \
# 0            0     0  2002      9    1  06:21  $134.09   Swipe Transaction
# 1            0     0  2002      9    1  06:42   $38.48   Swipe Transaction
# 2            0     0  2002      9    2  06:22  $120.34   Swipe Transaction
# 3            0     0  2002      9    2  17:45  $128.95   Swipe Transaction
# 4            0     0  2002      9    3  06:23  $104.71   Swipe Transaction
# ...        ...   ...   ...    ...  ...    ...      ...                 ...
# 16499995  1338     1  2004      8   21  16:55   $38.26  Online Transaction
# 16499996  1338     1  2004      8   22  10:49   $17.28   Swipe Transaction
# 16499997  1338     1  2004      8   22  11:55   $40.29  Online Transaction
# 16499998  1338     1  2004      8   23  11:50   $37.01  Online Transaction
# 16499999  1338     1  2004      8   23  16:40   $27.14  Online Transaction
#
#                 Merchant Name  Merchant City Merchant State      Zip   MCC  \
# 0         3527213246127876953       La Verne             CA  91750.0  5300
# 1         -727612092139916043  Monterey Park             CA  91754.0  5411
# 2         -727612092139916043  Monterey Park             CA  91754.0  5411
# 3         3414527459579106770  Monterey Park             CA  91754.0  5651
# 4         5817218446178736267       La Verne             CA  91750.0  5912
# ...                       ...            ...            ...      ...   ...
# 16499995 -2088492411650162548         ONLINE            NaN      NaN  4784
# 16499996 -6259030734646478313    Summerville             SC  29485.0  5812
# 16499997 -2088492411650162548         ONLINE            NaN      NaN  4784
# 16499998 -2088492411650162548         ONLINE            NaN      NaN  4784
# 16499999 -2088492411650162548         ONLINE            NaN      NaN  4784
#
#          Errors? Is Fraud?
# 0            NaN        No
# 1            NaN        No
# 2            NaN        No
# 3            NaN        No
# 4            NaN        No
# ...          ...       ...
# 16499995     NaN        No
# 16499996     NaN        No
# 16499997     NaN        No
# 16499998     NaN        No
# 16499999     NaN        No
#
# [16500000 rows x 15 columns]

# %%
# Set sequence length for multivariate time series
seq_length = 7

df['Merchant Name'] = df['Merchant Name'].astype(str)
df.sort_values(by=['User','Card'], inplace=True)
df.reset_index(inplace=True, drop=True)
print (df.info())

# Get first of each User-Card combination
first = df[['User','Card']].drop_duplicates()
f = np.array(first.index)

# Drop the first N transactions
drop_list = np.concatenate([np.arange(x,x + seq_length - 1) for x in f])
index_list = np.setdiff1d(df.index.values,drop_list)

# Split into 0.5 train, 0.3 validate, 0.2 test
tot_length = index_list.shape[0]
train_length = tot_length // 2
validate_length = (tot_length - train_length) * 3 // 5
test_length = tot_length - train_length - validate_length
print (tot_length,train_length,validate_length, test_length)

# Generate list of indices for train, validate, test
np.random.seed(1111)
train_indices = np.random.choice(index_list, train_length, replace=False)
tv_list = np.setdiff1d(index_list, train_indices)
validate_indices = np.random.choice(tv_list, validate_length, replace=False)
test_indices = np.setdiff1d(tv_list, validate_indices)
print(train_indices, validate_indices, test_indices)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16500000 entries, 0 to 16499999
# Data columns (total 15 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   User            int64
#  1   Card            int64
#  2   Year            int64
#  3   Month           int64
#  4   Day             int64
#  5   Time            object
#  6   Amount          object
#  7   Use Chip        object
#  8   Merchant Name   object
#  9   Merchant City   object
#  10  Merchant State  object
#  11  Zip             float64
#  12  MCC             int64
#  13  Errors?         object
#  14  Is Fraud?       object
# dtypes: float64(1), int64(6), object(8)
# memory usage: 1.8+ GB
# None
# 16475254 8237627 4942576 3295051
# [10564891  4293011 12990080 ...  7946973  8363815  6839602] [ 5898230  4785713  4951019 ...  3062006  6616067 11640215] [       6        8       27 ... 16499980 16499986 16499993]

# %%
# ----- CUSTOM MAPPING FUNCTIONS -----
def timeEncoder(X):
    X_hm = X['Time'].str.split(':', expand=True)
    d = pd.to_datetime(dict(year=X['Year'],month=X['Month'],day=X['Day'],hour=X_hm[0],minute=X_hm[1])).astype(int)
    return pd.DataFrame(d)

def amtEncoder(X):
    amt = X.apply(lambda x: x[1:]).astype(float).map(lambda amt: max(1,amt)).map(math.log)
    return pd.DataFrame(amt)

def decimalEncoder(X,length=5):
    dnew = pd.DataFrame()
    for i in range(length):
        dnew[i] = np.mod(X,10) 
        X = np.floor_divide(X,10)
    return dnew

def fraudEncoder(X):
    return np.where(X == 'Yes', 1, 0).astype(int)

# %%
from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelBinarizer
from sklearn.impute import SimpleImputer

mapper = DataFrameMapper([('Is Fraud?', FunctionTransformer(fraudEncoder)),
                          (['Merchant State'], [SimpleImputer(strategy='constant'), FunctionTransformer(np.ravel),
                                               LabelEncoder(), FunctionTransformer(decimalEncoder), OneHotEncoder()]),
                          (['Zip'], [SimpleImputer(strategy='constant'), FunctionTransformer(np.ravel),
                                     FunctionTransformer(decimalEncoder), OneHotEncoder()]),
                          ('Merchant Name', [LabelEncoder(), FunctionTransformer(decimalEncoder), OneHotEncoder()]),
                          ('Merchant City', [LabelEncoder(), FunctionTransformer(decimalEncoder), OneHotEncoder()]),
                          ('MCC', [LabelEncoder(), FunctionTransformer(decimalEncoder), OneHotEncoder()]),
                          (['Use Chip'], [SimpleImputer(strategy='constant'), LabelBinarizer()]),
                          (['Errors?'], [SimpleImputer(strategy='constant'), LabelBinarizer()]),
                          (['Year','Month','Day','Time'], [FunctionTransformer(timeEncoder), MinMaxScaler()]),
                          ('Amount', [FunctionTransformer(amtEncoder), MinMaxScaler()])
                         ], input_df=True, df_out=True)
mapper.fit(df)
# Out:
# DataFrameMapper(df_out=True, drop_cols=[],
#                 features=[('Is Fraud?',
#                            FunctionTransformer(func=<function fraudEncoder at 0x7f5223b39a20>)),
#                           (['Merchant State'],
#                            [SimpleImputer(strategy='constant'),
#                             FunctionTransformer(func=<function ravel at 0x7f52c0133490>),
#                             LabelEncoder(),
#                             FunctionTransformer(func=<function decimalEncoder at 0x7f5223b39240>),
#                             OneHotEncoder()]),
#                           (['Zip']...
#                           (['Use Chip'],
#                            [SimpleImputer(strategy='constant'),
#                             LabelBinarizer()]),
#                           (['Errors?'],
#                            [SimpleImputer(strategy='constant'),
#                             LabelBinarizer()]),
#                           (['Year', 'Month', 'Day', 'Time'],
#                            [FunctionTransformer(func=<function timeEncoder at 0x7f5223b39bd0>),
#                             MinMaxScaler()]),
#                           ('Amount',
#                            [FunctionTransformer(func=<function amtEncoder at 0x7f5223b392d0>),
#                             MinMaxScaler()])],
#                 input_df=True)

# %%
import joblib
mapper = joblib.load(open('/content/drive/MyDrive/University of Toronto Elec & Comp Eng/Capstone/saved_models/fitted_mapper.pkl','rb'))

# %%
mapped_sample = mapper.transform(df[:100])
mapped_size = mapped_sample.shape[-1]
print(mapped_size)
# Out:
# 220

# %%
def gen_training_batch(df, mapper, index_list, batch_size):
    np.random.seed(98765)
    train_df = df.loc[index_list]
    non_fraud_indices = train_df[train_df['Is Fraud?'] == 'No'].index.values
    fraud_indices = train_df[train_df['Is Fraud?'] == 'Yes'].index.values
    fsize = fraud_indices.shape[0]
    while True:
        indices = np.concatenate((fraud_indices,np.random.choice(non_fraud_indices,fsize,replace=False)))
        np.random.shuffle(indices)
        rows = indices.shape[0]
        index_array = np.zeros((rows, seq_length), dtype=int)
        for i in range(seq_length):
            index_array[:,i] = indices + 1 - seq_length + i
        full_df = mapper.transform(df.loc[index_array.flatten()])
        target_buffer = full_df['Is Fraud?'].to_numpy().reshape(rows, seq_length, 1)
        data_buffer = full_df.drop(['Is Fraud?'],axis=1).to_numpy().reshape(rows, seq_length, -1)

        batch_ptr = 0
        while (batch_ptr + batch_size) <= rows:
            data = data_buffer[batch_ptr:batch_ptr+batch_size]
            targets = target_buffer[batch_ptr:batch_ptr+batch_size]
            batch_ptr += batch_size
            data_t = np.transpose(data, axes=(1,0,2))
            targets_t = np.transpose(targets, axes=(1,0,2))
            yield data_t,targets_t

# %%
class TP(tf.keras.metrics.TruePositives):
    def update_state(self, y_true, y_pred, sample_weight=None):
        super().update_state(y_true[-1,:,:], y_pred[-1,:,:], sample_weight)

class FP(tf.keras.metrics.FalsePositives):
    def update_state(self, y_true, y_pred, sample_weight=None):
        super().update_state(y_true[-1,:,:], y_pred[-1,:,:], sample_weight)

class FN(tf.keras.metrics.FalseNegatives):
    def update_state(self, y_true, y_pred, sample_weight=None):
        super().update_state(y_true[-1,:,:], y_pred[-1,:,:], sample_weight)

class TN(tf.keras.metrics.TrueNegatives):
    def update_state(self, y_true, y_pred, sample_weight=None):
        super().update_state(y_true[-1,:,:], y_pred[-1,:,:], sample_weight)

# %%
units = [200,200]
input_size = mapped_size - 1
output_size = 1

batch_size = 16
tf_input = ([batch_size, input_size])

lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(units[0], input_shape=tf_input, batch_size=7, time_major=True, return_sequences=True),
    #Trying to set return_sequences to false here
    tf.keras.layers.LSTM(units[1], return_sequences=True, time_major=True),
    tf.keras.layers.Dense(output_size, activation='sigmoid')
])

lstm_model.summary()
tf.keras.utils.plot_model(lstm_model, '/content/drive/MyDrive/University of Toronto Elec & Comp Eng/Capstone/model.png', show_shapes=True)

metrics=['accuracy', 
    TP(name='TP'),
    FP(name='FP'),
    FN(name='FN'),
    TN(name='TN'),
    tf.keras.metrics.TruePositives(name='tp'),
    tf.keras.metrics.FalsePositives(name='fp'),
    tf.keras.metrics.FalseNegatives(name='fn'),
    tf.keras.metrics.TrueNegatives(name='tn')
   ]

lstm_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=metrics)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (7, 16, 200)              336000
#
#  lstm_9 (LSTM)               (7, 16, 200)              320800
#
#  dense_4 (Dense)             (7, 16, 1)                201
#
# =================================================================
# Total params: 657,001
# Trainable params: 657,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
steps_per_epoch = 10000
checkpoint_dir = "/content/drive/MyDrive/University of Toronto Elec & Comp Eng/Capstone/checkpoints/"
filepath = checkpoint_dir + "iter-{epoch:02d}/model.ckpt"
batch_size = 16

# %%
import warnings
warnings.filterwarnings("ignore")

print ("Learning...")
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=filepath, save_weights_only=True, verbose=1)
train_generate = gen_training_batch(df,mapper,train_indices,batch_size)
lstm_model.fit(train_generate, epochs=5, steps_per_epoch=steps_per_epoch, verbose=1, callbacks=[cp_callback])
# Out:
# Learning...
# Epoch 1/5
#  9999/10000 [============================>.] - ETA: 0s - loss: 0.0662 - accuracy: 0.9763 - TP: 76076.0000 - FP: 1338.0000 - FN: 3911.0000 - TN: 78659.0000 - tp: 243199.0000 - fp: 8586.0000 - fn: 17999.0000 - tn: 850104.0000
# Epoch 1: saving model to /content/drive/MyDrive/University of Toronto Elec & Comp Eng/Capstone/checkpoints/iter-01/model.ckpt
# 10000/10000 [==============================] - 464s 46ms/step - loss: 0.0661 - accuracy: 0.9763 - TP: 76085.0000 - FP: 1338.0000 - FN: 3911.0000 - TN: 78666.0000 - tp: 243232.0000 - fp: 8587.0000 - fn: 17999.0000 - tn: 850182.0000
# Epoch 2/5
#  9920/10000 [============================>.] - ETA: 3s - loss: 0.0153 - accuracy: 0.9944 - TP: 79003.0000 - FP: 326.0000 - FN: 364.0000 - TN: 79027.0000 - tp: 255745.0000 - fp: 2736.0000 - fn: 3462.0000 - tn: 849097.0000

# %%
lstm_model.save('/content/drive/MyDrive/University of Toronto Elec & Comp Eng/Capstone/saved_models/lstm_model_5_epochs_new.h5')

# %%
from tensorflow import keras
from keras.models import load_model

dependencies = {
    'TP': TP,
    'FP': FP,
    'TN': TN,
    'FN': FN
}

model = load_model('/content/drive/MyDrive/University of Toronto Elec & Comp Eng/Capstone/saved_models/lstm_model_5_epochs.h5', custom_objects=dependencies)

# %%
def gen_test_batch(df, mapper, indices, batch_size):
    rows = indices.shape[0]
    index_array = np.zeros((rows, seq_length), dtype=np.int)
    for i in range(seq_length):
        index_array[:,i] = indices + 1 - seq_length + i
    count = 0
    while (count + batch_size <= rows):        
        full_df = mapper.transform(df.loc[index_array[count:count+batch_size].flatten()])
        data = full_df.drop(['Is Fraud?'],axis=1).to_numpy().reshape(batch_size, seq_length, -1)
        targets = full_df['Is Fraud?'].to_numpy().reshape(batch_size, seq_length, 1)
        count += batch_size
        data_t = np.transpose(data, axes=(1,0,2))
        targets_t = np.transpose(targets, axes=(1,0,2))
        yield data_t, targets_t

# %%
batch_size = 16

print("\nFull test")
test_generate = gen_test_batch(df,mapper,test_indices,batch_size)
lstm_model.evaluate(test_generate, verbose=1)

# %% [markdown]
# #**ADABOOST**

# %%
def gen_training_batch(df, mapper, index_list, batch_size):
    np.random.seed(98765)
    train_df = df.loc[index_list]
    non_fraud_indices = train_df[train_df['Is Fraud?'] == 'No'].index.values
    fraud_indices = train_df[train_df['Is Fraud?'] == 'Yes'].index.values
    fsize = fraud_indices.shape[0]
    while True:
        indices = np.concatenate((fraud_indices,np.random.choice(non_fraud_indices,fsize,replace=False)))
        np.random.shuffle(indices)
        rows = indices.shape[0]
        index_array = np.zeros((rows, seq_length), dtype=int)
        for i in range(seq_length):
            index_array[:,i] = indices + 1 - seq_length + i
        full_df = mapper.transform(df.loc[index_array.flatten()])
        target_buffer = full_df['Is Fraud?'].to_numpy().reshape(rows, seq_length, 1)
        data_buffer = full_df.drop(['Is Fraud?'],axis=1).to_numpy().reshape(rows, seq_length, -1)

        batch_ptr = 0
        while (batch_ptr + batch_size) <= rows:
            data = data_buffer[batch_ptr:batch_ptr+batch_size]
            targets = target_buffer[batch_ptr:batch_ptr+batch_size]
            batch_ptr += batch_size
            data_t = np.transpose(data, axes=(1,0,2))
            targets_t = np.transpose(targets, axes=(1,0,2))
            yield data_t.reshape(-1, data_t.shape[-1]), targets_t.reshape(-1)

# %%
from sklearn.ensemble import AdaBoostClassifier
# Train multiple models using Adaboost
ada = AdaBoostClassifier(n_estimators=10, learning_rate=5)
print(ada)

# Fit the classifier using the training batch
num_epochs = 50
for i in range(num_epochs):
    X_batch, y_batch = next(gen_training_batch(df, mapper, train_indices, 16))
    ada.fit(X_batch, y_batch)
# Out:
# AdaBoostClassifier(learning_rate=5, n_estimators=10)

# %%
from joblib import dump, load
print(ada)

# Save the fitted model to a file
dump(ada, '/content/drive/MyDrive/University of Toronto Elec & Comp Eng/Capstone/saved_models/adaboost_model_50epochs_10estimators_5LR.joblib')
# Out:
# AdaBoostClassifier(learning_rate=5, n_estimators=10)
# ['/content/drive/MyDrive/University of Toronto Elec & Comp Eng/Capstone/saved_models/adaboost_model_50epochs_10estimators_5LR.joblib']

# %%
from joblib import dump, load
from sklearn.ensemble import AdaBoostClassifier
# Load the AdaBoost model that was saved
ada = load('/content/drive/MyDrive/University of Toronto Elec & Comp Eng/Capstone/saved_models/adaboost_model_50epochs_10estimators.joblib')

# %%
def evaluate_model(y_true, y_pred):
    tp = np.sum((y_true == 1) & (y_pred == 1))
    tn = np.sum((y_true == 0) & (y_pred == 0))
    fp = np.sum((y_true == 0) & (y_pred == 1))
    fn = np.sum((y_true == 1) & (y_pred == 0))
    
    precision = tp / (tp + fp + 1e-8)
    recall = tp / (tp + fn + 1e-8)
    f1_score = 2 * (precision * recall) / (precision + recall + 1e-8)
    
    return tp, tn, fp, fn

# %%
def gen_test_batch(df, mapper, indices, batch_size):
    rows = indices.shape[0]
    index_array = np.zeros((rows, seq_length), dtype=np.int)
    for i in range(seq_length):
        index_array[:,i] = indices + 1 - seq_length + i
    count = 0
    while (count + batch_size <= rows):        
        full_df = mapper.transform(df.loc[index_array[count:count+batch_size].flatten()])
        data = full_df.drop(['Is Fraud?'],axis=1).to_numpy().reshape(batch_size, seq_length, -1)
        targets = full_df['Is Fraud?'].to_numpy().reshape(batch_size, seq_length, 1)
        count += batch_size
        data_t = np.transpose(data, axes=(1,0,2))
        targets_t = np.transpose(targets, axes=(1,0,2))
        yield data_t.reshape(-1, data_t.shape[-1]), targets_t.reshape(-1)

# Generate test batches
test_batches = gen_test_batch(df, mapper, test_indices, batch_size=16)

# Evaluate the model on the test data
total_accuracy = 0
total_fp_rate = 0
total_tp_rate = 0
total_tn_rate = 0
total_fn_rate = 0
num_batches = 1000  # number of test batches to evaluate
total_actual_fraud = 0
total_actual_non_fraud = 0

# --------------------------- Time Metrics ---------------------------
import time
total_time_pred = 0


for i in range(num_batches):
    X_batch, y_batch = next(test_batches)
    # Make all predictions above 0.35 into positive predictions
    start_time = time.time()
    y_pred = (ada.predict_proba(X_batch)[:, 1] >= 0.5).astype(int)
    end_time = time.time()
    total_time_pred += (end_time - start_time)
    accuracy = np.mean(y_pred == y_batch)
    total_accuracy += accuracy
    tp_rate, tn_rate, fp_rate, fn_rate = evaluate_model(y_batch.reshape(-1), y_pred)

    for x in y_batch.reshape(-1):
      if x == 0:
        total_actual_non_fraud += 1
      elif x == 1:
        total_actual_fraud += 1

    total_fp_rate += fp_rate
    total_tp_rate += tp_rate
    total_tn_rate += tn_rate
    total_fn_rate += fn_rate
    print("Batch {}: accuracy = {:.4f}, true positive rate = {:.4f}, false positives rate = {:.4f}, true negative rate = {:.4f}, false negative rate = {:.4f}".format(i+1, accuracy, tp_rate, fp_rate, tn_rate, fn_rate))
    fraud_count = np.sum(y_batch)
    non_fraud_count = y_batch.shape[0] - fraud_count
    print("Batch {}: fraud count = {}, non-fraud count = {}".format(i+1, fraud_count, non_fraud_count))

avg_accuracy = total_accuracy / num_batches
avg_fp_rate = total_fp_rate / num_batches
avg_tp_rate = total_tp_rate / num_batches
avg_fn_rate = total_fn_rate / num_batches
avg_tn_rate = total_tn_rate / num_batches
print("Average accuracy on test data: {:.4f}".format(avg_accuracy))
'''
print("Average false positives rate on test data: {:.4f}".format(avg_fp_rate))
print("Average true positives rate on test data: {:.4f}".format(avg_tp_rate))
print("Average false negatives rate on test data: {:.4f}".format(avg_fn_rate))
print("Average true negatives rate on test data: {:.4f}".format(avg_tn_rate))
'''
print("The number of transactions processed per second is: ", ((16*7*num_batches) / total_time_pred))

print("The total number of false positives from the set is: ", total_fp_rate)
print("The total number of false negatives from the set is: ", total_fn_rate)
print("The total number of true positives from the set is: ", total_tp_rate)
print("The total number of true negatives from the set is: ", total_tn_rate)

precision = total_tp_rate / (total_tp_rate + total_fp_rate)
recall = total_tp_rate / (total_tp_rate + total_fn_rate)
f1_score = 2 * (precision * recall) / (precision + recall)
print("The precision score from the set is: ", precision)
print("The recall score from the set is: ", recall)
print("The f1 score from the set is: ", f1_score)

fp_rate = total_fp_rate / (total_fp_rate + total_tn_rate)
print("The false positive rate is: ", fp_rate)

fn_rate = total_fn_rate / (total_fn_rate + total_tp_rate)
print("The false negative rate is: ", fn_rate)

print('The actual number of non-fraud in this set is: ', total_actual_non_fraud)
print('The actual number of fraud in this set is: ', total_actual_fraud)
# Out:
# <ipython-input-9-80bf26c3f720>:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   index_array = np.zeros((rows, seq_length), dtype=np.int)
# Batch 1: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 1: fraud count = 0, non-fraud count = 112
# Batch 2: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 2: fraud count = 0, non-fraud count = 112
# Batch 3: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 3: fraud count = 0, non-fraud count = 112
# Batch 4: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 4: fraud count = 0, non-fraud count = 112
# Batch 5: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 5: fraud count = 0, non-fraud count = 112
# Batch 6: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 6: fraud count = 0, non-fraud count = 112
# Batch 7: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 7: fraud count = 0, non-fraud count = 112
# Batch 8: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 8: fraud count = 0, non-fraud count = 112
# Batch 9: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 9: fraud count = 0, non-fraud count = 112
# Batch 10: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 10: fraud count = 0, non-fraud count = 112
# Batch 11: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 11: fraud count = 0, non-fraud count = 112
# Batch 12: accuracy = 0.8839, true positive rate = 0.0000, false positives rate = 13.0000, true negative rate = 99.0000, false negative rate = 0.0000
# Batch 12: fraud count = 0, non-fraud count = 112
# Batch 13: accuracy = 0.8839, true positive rate = 0.0000, false positives rate = 13.0000, true negative rate = 99.0000, false negative rate = 0.0000
# Batch 13: fraud count = 0, non-fraud count = 112
# Batch 14: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 14: fraud count = 0, non-fraud count = 112
# Batch 15: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 15: fraud count = 0, non-fraud count = 112
# Batch 16: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 16: fraud count = 0, non-fraud count = 112
# Batch 17: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 17: fraud count = 0, non-fraud count = 112
# Batch 18: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 18: fraud count = 0, non-fraud count = 112
# Batch 19: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 19: fraud count = 0, non-fraud count = 112
# Batch 20: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 20: fraud count = 0, non-fraud count = 112
# Batch 21: accuracy = 0.8571, true positive rate = 0.0000, false positives rate = 16.0000, true negative rate = 96.0000, false negative rate = 0.0000
# Batch 21: fraud count = 0, non-fraud count = 112
# Batch 22: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 22: fraud count = 0, non-fraud count = 112
# Batch 23: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 23: fraud count = 0, non-fraud count = 112
# Batch 24: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 24: fraud count = 0, non-fraud count = 112
# Batch 25: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 25: fraud count = 0, non-fraud count = 112
# Batch 26: accuracy = 0.9196, true positive rate = 0.0000, false positives rate = 9.0000, true negative rate = 103.0000, false negative rate = 0.0000
# Batch 26: fraud count = 0, non-fraud count = 112
# Batch 27: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 27: fraud count = 0, non-fraud count = 112
# Batch 28: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 28: fraud count = 0, non-fraud count = 112
# Batch 29: accuracy = 0.8571, true positive rate = 0.0000, false positives rate = 16.0000, true negative rate = 96.0000, false negative rate = 0.0000
# Batch 29: fraud count = 0, non-fraud count = 112
# Batch 30: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 30: fraud count = 0, non-fraud count = 112
# Batch 31: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 31: fraud count = 0, non-fraud count = 112
# Batch 32: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 32: fraud count = 0, non-fraud count = 112
# Batch 33: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 33: fraud count = 0, non-fraud count = 112
# Batch 34: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 34: fraud count = 0, non-fraud count = 112
# Batch 35: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 35: fraud count = 0, non-fraud count = 112
# Batch 36: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 36: fraud count = 0, non-fraud count = 112
# Batch 37: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 37: fraud count = 0, non-fraud count = 112
# Batch 38: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 38: fraud count = 0, non-fraud count = 112
# Batch 39: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 39: fraud count = 0, non-fraud count = 112
# Batch 40: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 40: fraud count = 0, non-fraud count = 112
# Batch 41: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 41: fraud count = 0, non-fraud count = 112
# Batch 42: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 42: fraud count = 0, non-fraud count = 112
# Batch 43: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 43: fraud count = 0, non-fraud count = 112
# Batch 44: accuracy = 0.9196, true positive rate = 0.0000, false positives rate = 9.0000, true negative rate = 103.0000, false negative rate = 0.0000
# Batch 44: fraud count = 0, non-fraud count = 112
# Batch 45: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 45: fraud count = 0, non-fraud count = 112
# Batch 46: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 46: fraud count = 0, non-fraud count = 112
# Batch 47: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 47: fraud count = 0, non-fraud count = 112
# Batch 48: accuracy = 0.8214, true positive rate = 0.0000, false positives rate = 20.0000, true negative rate = 92.0000, false negative rate = 0.0000
# Batch 48: fraud count = 0, non-fraud count = 112
# Batch 49: accuracy = 0.8661, true positive rate = 0.0000, false positives rate = 15.0000, true negative rate = 97.0000, false negative rate = 0.0000
# Batch 49: fraud count = 0, non-fraud count = 112
# Batch 50: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 50: fraud count = 0, non-fraud count = 112
# Batch 51: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 51: fraud count = 0, non-fraud count = 112
# Batch 52: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 52: fraud count = 0, non-fraud count = 112
# Batch 53: accuracy = 0.9821, true positive rate = 26.0000, false positives rate = 2.0000, true negative rate = 84.0000, false negative rate = 0.0000
# Batch 53: fraud count = 26, non-fraud count = 86
# Batch 54: accuracy = 0.9286, true positive rate = 0.0000, false positives rate = 8.0000, true negative rate = 104.0000, false negative rate = 0.0000
# Batch 54: fraud count = 0, non-fraud count = 112
# Batch 55: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 55: fraud count = 0, non-fraud count = 112
# Batch 56: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 56: fraud count = 0, non-fraud count = 112
# Batch 57: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 57: fraud count = 0, non-fraud count = 112
# Batch 58: accuracy = 0.9196, true positive rate = 0.0000, false positives rate = 9.0000, true negative rate = 103.0000, false negative rate = 0.0000
# Batch 58: fraud count = 0, non-fraud count = 112
# Batch 59: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 59: fraud count = 0, non-fraud count = 112
# Batch 60: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 60: fraud count = 0, non-fraud count = 112
# Batch 61: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 61: fraud count = 0, non-fraud count = 112
# Batch 62: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 62: fraud count = 0, non-fraud count = 112
# Batch 63: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 63: fraud count = 0, non-fraud count = 112
# Batch 64: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 64: fraud count = 0, non-fraud count = 112
# Batch 65: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 65: fraud count = 0, non-fraud count = 112
# Batch 66: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 66: fraud count = 0, non-fraud count = 112
# Batch 67: accuracy = 0.9286, true positive rate = 0.0000, false positives rate = 8.0000, true negative rate = 104.0000, false negative rate = 0.0000
# Batch 67: fraud count = 0, non-fraud count = 112
# Batch 68: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 68: fraud count = 0, non-fraud count = 112
# Batch 69: accuracy = 0.9018, true positive rate = 0.0000, false positives rate = 11.0000, true negative rate = 101.0000, false negative rate = 0.0000
# Batch 69: fraud count = 0, non-fraud count = 112
# Batch 70: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 70: fraud count = 0, non-fraud count = 112
# Batch 71: accuracy = 0.8304, true positive rate = 0.0000, false positives rate = 19.0000, true negative rate = 93.0000, false negative rate = 0.0000
# Batch 71: fraud count = 0, non-fraud count = 112
# Batch 72: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 72: fraud count = 0, non-fraud count = 112
# Batch 73: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 73: fraud count = 0, non-fraud count = 112
# Batch 74: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 74: fraud count = 0, non-fraud count = 112
# Batch 75: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 75: fraud count = 0, non-fraud count = 112
# Batch 76: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 76: fraud count = 0, non-fraud count = 112
# Batch 77: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 77: fraud count = 0, non-fraud count = 112
# Batch 78: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 78: fraud count = 0, non-fraud count = 112
# Batch 79: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 79: fraud count = 0, non-fraud count = 112
# Batch 80: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 80: fraud count = 0, non-fraud count = 112
# Batch 81: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 81: fraud count = 0, non-fraud count = 112
# Batch 82: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 82: fraud count = 0, non-fraud count = 112
# Batch 83: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 83: fraud count = 0, non-fraud count = 112
# Batch 84: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 84: fraud count = 0, non-fraud count = 112
# Batch 85: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 85: fraud count = 0, non-fraud count = 112
# Batch 86: accuracy = 0.8393, true positive rate = 0.0000, false positives rate = 18.0000, true negative rate = 94.0000, false negative rate = 0.0000
# Batch 86: fraud count = 0, non-fraud count = 112
# Batch 87: accuracy = 0.9196, true positive rate = 0.0000, false positives rate = 9.0000, true negative rate = 103.0000, false negative rate = 0.0000
# Batch 87: fraud count = 0, non-fraud count = 112
# Batch 88: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 88: fraud count = 0, non-fraud count = 112
# Batch 89: accuracy = 0.8750, true positive rate = 0.0000, false positives rate = 14.0000, true negative rate = 98.0000, false negative rate = 0.0000
# Batch 89: fraud count = 0, non-fraud count = 112
# Batch 90: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 90: fraud count = 0, non-fraud count = 112
# Batch 91: accuracy = 0.8214, true positive rate = 0.0000, false positives rate = 20.0000, true negative rate = 92.0000, false negative rate = 0.0000
# Batch 91: fraud count = 0, non-fraud count = 112
# Batch 92: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 92: fraud count = 0, non-fraud count = 112
# Batch 93: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 93: fraud count = 0, non-fraud count = 112
# Batch 94: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 94: fraud count = 0, non-fraud count = 112
# Batch 95: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 95: fraud count = 0, non-fraud count = 112
# Batch 96: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 96: fraud count = 0, non-fraud count = 112
# Batch 97: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 97: fraud count = 0, non-fraud count = 112
# Batch 98: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 98: fraud count = 0, non-fraud count = 112
# Batch 99: accuracy = 0.9196, true positive rate = 0.0000, false positives rate = 9.0000, true negative rate = 103.0000, false negative rate = 0.0000
# Batch 99: fraud count = 0, non-fraud count = 112
# Batch 100: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 100: fraud count = 0, non-fraud count = 112
# Batch 101: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 101: fraud count = 0, non-fraud count = 112
# Batch 102: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 102: fraud count = 0, non-fraud count = 112
# Batch 103: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 103: fraud count = 0, non-fraud count = 112
# Batch 104: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 104: fraud count = 0, non-fraud count = 112
# Batch 105: accuracy = 0.9018, true positive rate = 0.0000, false positives rate = 11.0000, true negative rate = 101.0000, false negative rate = 0.0000
# Batch 105: fraud count = 0, non-fraud count = 112
# Batch 106: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 106: fraud count = 0, non-fraud count = 112
# Batch 107: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 107: fraud count = 0, non-fraud count = 112
# Batch 108: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 108: fraud count = 0, non-fraud count = 112
# Batch 109: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 109: fraud count = 0, non-fraud count = 112
# Batch 110: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 110: fraud count = 0, non-fraud count = 112
# Batch 111: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 111: fraud count = 0, non-fraud count = 112
# Batch 112: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 112: fraud count = 0, non-fraud count = 112
# Batch 113: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 113: fraud count = 0, non-fraud count = 112
# Batch 114: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 114: fraud count = 0, non-fraud count = 112
# Batch 115: accuracy = 0.8393, true positive rate = 0.0000, false positives rate = 18.0000, true negative rate = 94.0000, false negative rate = 0.0000
# Batch 115: fraud count = 0, non-fraud count = 112
# Batch 116: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 116: fraud count = 0, non-fraud count = 112
# Batch 117: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 117: fraud count = 0, non-fraud count = 112
# Batch 118: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 118: fraud count = 0, non-fraud count = 112
# Batch 119: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 119: fraud count = 0, non-fraud count = 112
# Batch 120: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 120: fraud count = 0, non-fraud count = 112
# Batch 121: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 121: fraud count = 0, non-fraud count = 112
# Batch 122: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 122: fraud count = 0, non-fraud count = 112
# Batch 123: accuracy = 0.8750, true positive rate = 1.0000, false positives rate = 12.0000, true negative rate = 97.0000, false negative rate = 2.0000
# Batch 123: fraud count = 3, non-fraud count = 109
# Batch 124: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 124: fraud count = 0, non-fraud count = 112
# Batch 125: accuracy = 0.9196, true positive rate = 0.0000, false positives rate = 9.0000, true negative rate = 103.0000, false negative rate = 0.0000
# Batch 125: fraud count = 0, non-fraud count = 112
# Batch 126: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 126: fraud count = 0, non-fraud count = 112
# Batch 127: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 127: fraud count = 0, non-fraud count = 112
# Batch 128: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 128: fraud count = 0, non-fraud count = 112
# Batch 129: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 129: fraud count = 0, non-fraud count = 112
# Batch 130: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 130: fraud count = 0, non-fraud count = 112
# Batch 131: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 131: fraud count = 0, non-fraud count = 112
# Batch 132: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 132: fraud count = 0, non-fraud count = 112
# Batch 133: accuracy = 0.8214, true positive rate = 0.0000, false positives rate = 20.0000, true negative rate = 92.0000, false negative rate = 0.0000
# Batch 133: fraud count = 0, non-fraud count = 112
# Batch 134: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 134: fraud count = 0, non-fraud count = 112
# Batch 135: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 135: fraud count = 0, non-fraud count = 112
# Batch 136: accuracy = 0.9107, true positive rate = 0.0000, false positives rate = 10.0000, true negative rate = 102.0000, false negative rate = 0.0000
# Batch 136: fraud count = 0, non-fraud count = 112
# Batch 137: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 137: fraud count = 0, non-fraud count = 112
# Batch 138: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 138: fraud count = 0, non-fraud count = 112
# Batch 139: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 139: fraud count = 0, non-fraud count = 112
# Batch 140: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 140: fraud count = 0, non-fraud count = 112
# Batch 141: accuracy = 0.9107, true positive rate = 0.0000, false positives rate = 10.0000, true negative rate = 102.0000, false negative rate = 0.0000
# Batch 141: fraud count = 0, non-fraud count = 112
# Batch 142: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 142: fraud count = 0, non-fraud count = 112
# Batch 143: accuracy = 0.9107, true positive rate = 0.0000, false positives rate = 10.0000, true negative rate = 102.0000, false negative rate = 0.0000
# Batch 143: fraud count = 0, non-fraud count = 112
# Batch 144: accuracy = 0.9107, true positive rate = 0.0000, false positives rate = 10.0000, true negative rate = 102.0000, false negative rate = 0.0000
# Batch 144: fraud count = 0, non-fraud count = 112
# Batch 145: accuracy = 0.9286, true positive rate = 0.0000, false positives rate = 8.0000, true negative rate = 104.0000, false negative rate = 0.0000
# Batch 145: fraud count = 0, non-fraud count = 112
# Batch 146: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 146: fraud count = 0, non-fraud count = 112
# Batch 147: accuracy = 0.8304, true positive rate = 0.0000, false positives rate = 19.0000, true negative rate = 93.0000, false negative rate = 0.0000
# Batch 147: fraud count = 0, non-fraud count = 112
# Batch 148: accuracy = 0.9107, true positive rate = 0.0000, false positives rate = 10.0000, true negative rate = 102.0000, false negative rate = 0.0000
# Batch 148: fraud count = 0, non-fraud count = 112
# Batch 149: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 149: fraud count = 0, non-fraud count = 112
# Batch 150: accuracy = 0.7857, true positive rate = 0.0000, false positives rate = 24.0000, true negative rate = 88.0000, false negative rate = 0.0000
# Batch 150: fraud count = 0, non-fraud count = 112
# Batch 151: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 151: fraud count = 0, non-fraud count = 112
# Batch 152: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 152: fraud count = 0, non-fraud count = 112
# Batch 153: accuracy = 0.9018, true positive rate = 0.0000, false positives rate = 11.0000, true negative rate = 101.0000, false negative rate = 0.0000
# Batch 153: fraud count = 0, non-fraud count = 112
# Batch 154: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 154: fraud count = 0, non-fraud count = 112
# Batch 155: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 155: fraud count = 0, non-fraud count = 112
# Batch 156: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 156: fraud count = 0, non-fraud count = 112
# Batch 157: accuracy = 0.7500, true positive rate = 0.0000, false positives rate = 28.0000, true negative rate = 84.0000, false negative rate = 0.0000
# Batch 157: fraud count = 0, non-fraud count = 112
# Batch 158: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 158: fraud count = 0, non-fraud count = 112
# Batch 159: accuracy = 0.9286, true positive rate = 0.0000, false positives rate = 8.0000, true negative rate = 104.0000, false negative rate = 0.0000
# Batch 159: fraud count = 0, non-fraud count = 112
# Batch 160: accuracy = 0.7589, true positive rate = 0.0000, false positives rate = 27.0000, true negative rate = 85.0000, false negative rate = 0.0000
# Batch 160: fraud count = 0, non-fraud count = 112
# Batch 161: accuracy = 0.9018, true positive rate = 0.0000, false positives rate = 11.0000, true negative rate = 101.0000, false negative rate = 0.0000
# Batch 161: fraud count = 0, non-fraud count = 112
# Batch 162: accuracy = 0.8661, true positive rate = 0.0000, false positives rate = 15.0000, true negative rate = 97.0000, false negative rate = 0.0000
# Batch 162: fraud count = 0, non-fraud count = 112
# Batch 163: accuracy = 0.9286, true positive rate = 0.0000, false positives rate = 8.0000, true negative rate = 104.0000, false negative rate = 0.0000
# Batch 163: fraud count = 0, non-fraud count = 112
# Batch 164: accuracy = 0.9107, true positive rate = 0.0000, false positives rate = 10.0000, true negative rate = 102.0000, false negative rate = 0.0000
# Batch 164: fraud count = 0, non-fraud count = 112
# Batch 165: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 165: fraud count = 0, non-fraud count = 112
# Batch 166: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 166: fraud count = 0, non-fraud count = 112
# Batch 167: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 167: fraud count = 0, non-fraud count = 112
# Batch 168: accuracy = 0.9196, true positive rate = 0.0000, false positives rate = 9.0000, true negative rate = 103.0000, false negative rate = 0.0000
# Batch 168: fraud count = 0, non-fraud count = 112
# Batch 169: accuracy = 0.9018, true positive rate = 0.0000, false positives rate = 11.0000, true negative rate = 101.0000, false negative rate = 0.0000
# Batch 169: fraud count = 0, non-fraud count = 112
# Batch 170: accuracy = 0.8304, true positive rate = 0.0000, false positives rate = 19.0000, true negative rate = 93.0000, false negative rate = 0.0000
# Batch 170: fraud count = 0, non-fraud count = 112
# Batch 171: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 171: fraud count = 0, non-fraud count = 112
# Batch 172: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 172: fraud count = 0, non-fraud count = 112
# Batch 173: accuracy = 0.9018, true positive rate = 0.0000, false positives rate = 11.0000, true negative rate = 101.0000, false negative rate = 0.0000
# Batch 173: fraud count = 0, non-fraud count = 112
# Batch 174: accuracy = 0.8125, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 91.0000, false negative rate = 20.0000
# Batch 174: fraud count = 20, non-fraud count = 92
# Batch 175: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 175: fraud count = 0, non-fraud count = 112
# Batch 176: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 176: fraud count = 0, non-fraud count = 112
# Batch 177: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 177: fraud count = 0, non-fraud count = 112
# Batch 178: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 178: fraud count = 0, non-fraud count = 112
# Batch 179: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 179: fraud count = 0, non-fraud count = 112
# Batch 180: accuracy = 0.8839, true positive rate = 0.0000, false positives rate = 13.0000, true negative rate = 99.0000, false negative rate = 0.0000
# Batch 180: fraud count = 0, non-fraud count = 112
# Batch 181: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 181: fraud count = 0, non-fraud count = 112
# Batch 182: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 182: fraud count = 0, non-fraud count = 112
# Batch 183: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 183: fraud count = 0, non-fraud count = 112
# Batch 184: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 184: fraud count = 0, non-fraud count = 112
# Batch 185: accuracy = 0.9286, true positive rate = 0.0000, false positives rate = 8.0000, true negative rate = 104.0000, false negative rate = 0.0000
# Batch 185: fraud count = 0, non-fraud count = 112
# Batch 186: accuracy = 0.9286, true positive rate = 0.0000, false positives rate = 8.0000, true negative rate = 104.0000, false negative rate = 0.0000
# Batch 186: fraud count = 0, non-fraud count = 112
# Batch 187: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 187: fraud count = 0, non-fraud count = 112
# Batch 188: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 188: fraud count = 0, non-fraud count = 112
# Batch 189: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 189: fraud count = 0, non-fraud count = 112
# Batch 190: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 190: fraud count = 0, non-fraud count = 112
# Batch 191: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 191: fraud count = 0, non-fraud count = 112
# Batch 192: accuracy = 0.9018, true positive rate = 0.0000, false positives rate = 11.0000, true negative rate = 101.0000, false negative rate = 0.0000
# Batch 192: fraud count = 0, non-fraud count = 112
# Batch 193: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 193: fraud count = 0, non-fraud count = 112
# Batch 194: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 194: fraud count = 0, non-fraud count = 112
# Batch 195: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 195: fraud count = 0, non-fraud count = 112
# Batch 196: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 196: fraud count = 0, non-fraud count = 112
# Batch 197: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 197: fraud count = 0, non-fraud count = 112
# Batch 198: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 198: fraud count = 0, non-fraud count = 112
# Batch 199: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 199: fraud count = 0, non-fraud count = 112
# Batch 200: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 200: fraud count = 0, non-fraud count = 112
# Batch 201: accuracy = 0.9018, true positive rate = 0.0000, false positives rate = 11.0000, true negative rate = 101.0000, false negative rate = 0.0000
# Batch 201: fraud count = 0, non-fraud count = 112
# Batch 202: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 202: fraud count = 0, non-fraud count = 112
# Batch 203: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 203: fraud count = 0, non-fraud count = 112
# Batch 204: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 204: fraud count = 0, non-fraud count = 112
# Batch 205: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 205: fraud count = 0, non-fraud count = 112
# Batch 206: accuracy = 0.7411, true positive rate = 0.0000, false positives rate = 29.0000, true negative rate = 83.0000, false negative rate = 0.0000
# Batch 206: fraud count = 0, non-fraud count = 112
# Batch 207: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 207: fraud count = 0, non-fraud count = 112
# Batch 208: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 208: fraud count = 0, non-fraud count = 112
# Batch 209: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 209: fraud count = 0, non-fraud count = 112
# Batch 210: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 210: fraud count = 0, non-fraud count = 112
# Batch 211: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 211: fraud count = 0, non-fraud count = 112
# Batch 212: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 212: fraud count = 0, non-fraud count = 112
# Batch 213: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 213: fraud count = 0, non-fraud count = 112
# Batch 214: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 214: fraud count = 0, non-fraud count = 112
# Batch 215: accuracy = 0.9286, true positive rate = 0.0000, false positives rate = 8.0000, true negative rate = 104.0000, false negative rate = 0.0000
# Batch 215: fraud count = 0, non-fraud count = 112
# Batch 216: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 216: fraud count = 0, non-fraud count = 112
# Batch 217: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 217: fraud count = 0, non-fraud count = 112
# Batch 218: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 218: fraud count = 0, non-fraud count = 112
# Batch 219: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 219: fraud count = 0, non-fraud count = 112
# Batch 220: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 220: fraud count = 0, non-fraud count = 112
# Batch 221: accuracy = 0.9643, true positive rate = 1.0000, false positives rate = 3.0000, true negative rate = 107.0000, false negative rate = 1.0000
# Batch 221: fraud count = 2, non-fraud count = 110
# Batch 222: accuracy = 0.8304, true positive rate = 0.0000, false positives rate = 18.0000, true negative rate = 93.0000, false negative rate = 1.0000
# Batch 222: fraud count = 1, non-fraud count = 111
# Batch 223: accuracy = 0.7500, true positive rate = 0.0000, false positives rate = 28.0000, true negative rate = 84.0000, false negative rate = 0.0000
# Batch 223: fraud count = 0, non-fraud count = 112
# Batch 224: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 224: fraud count = 0, non-fraud count = 112
# Batch 225: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 225: fraud count = 0, non-fraud count = 112
# Batch 226: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 226: fraud count = 0, non-fraud count = 112
# Batch 227: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 227: fraud count = 0, non-fraud count = 112
# Batch 228: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 228: fraud count = 0, non-fraud count = 112
# Batch 229: accuracy = 0.9107, true positive rate = 0.0000, false positives rate = 10.0000, true negative rate = 102.0000, false negative rate = 0.0000
# Batch 229: fraud count = 0, non-fraud count = 112
# Batch 230: accuracy = 0.8661, true positive rate = 0.0000, false positives rate = 15.0000, true negative rate = 97.0000, false negative rate = 0.0000
# Batch 230: fraud count = 0, non-fraud count = 112
# Batch 231: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 231: fraud count = 0, non-fraud count = 112
# Batch 232: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 232: fraud count = 0, non-fraud count = 112
# Batch 233: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 233: fraud count = 0, non-fraud count = 112
# Batch 234: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 234: fraud count = 0, non-fraud count = 112
# Batch 235: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 235: fraud count = 0, non-fraud count = 112
# Batch 236: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 236: fraud count = 0, non-fraud count = 112
# Batch 237: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 237: fraud count = 0, non-fraud count = 112
# Batch 238: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 238: fraud count = 0, non-fraud count = 112
# ...
# Batch 924: fraud count = 0, non-fraud count = 112
# Batch 925: accuracy = 0.9018, true positive rate = 6.0000, false positives rate = 10.0000, true negative rate = 95.0000, false negative rate = 1.0000
# Batch 925: fraud count = 7, non-fraud count = 105
# Batch 926: accuracy = 0.9375, true positive rate = 12.0000, false positives rate = 5.0000, true negative rate = 93.0000, false negative rate = 2.0000
# Batch 926: fraud count = 14, non-fraud count = 98
# Batch 927: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 927: fraud count = 0, non-fraud count = 112
# Batch 928: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 928: fraud count = 0, non-fraud count = 112
# Batch 929: accuracy = 0.8750, true positive rate = 0.0000, false positives rate = 14.0000, true negative rate = 98.0000, false negative rate = 0.0000
# Batch 929: fraud count = 0, non-fraud count = 112
# Batch 930: accuracy = 0.8482, true positive rate = 5.0000, false positives rate = 15.0000, true negative rate = 90.0000, false negative rate = 2.0000
# Batch 930: fraud count = 7, non-fraud count = 105
# Batch 931: accuracy = 0.9911, true positive rate = 10.0000, false positives rate = 1.0000, true negative rate = 101.0000, false negative rate = 0.0000
# Batch 931: fraud count = 10, non-fraud count = 102
# Batch 932: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 932: fraud count = 0, non-fraud count = 112
# Batch 933: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 933: fraud count = 0, non-fraud count = 112
# Batch 934: accuracy = 0.8839, true positive rate = 0.0000, false positives rate = 13.0000, true negative rate = 99.0000, false negative rate = 0.0000
# Batch 934: fraud count = 0, non-fraud count = 112
# Batch 935: accuracy = 0.8929, true positive rate = 0.0000, false positives rate = 12.0000, true negative rate = 100.0000, false negative rate = 0.0000
# Batch 935: fraud count = 0, non-fraud count = 112
# Batch 936: accuracy = 0.9821, true positive rate = 0.0000, false positives rate = 2.0000, true negative rate = 110.0000, false negative rate = 0.0000
# Batch 936: fraud count = 0, non-fraud count = 112
# Batch 937: accuracy = 0.9286, true positive rate = 0.0000, false positives rate = 8.0000, true negative rate = 104.0000, false negative rate = 0.0000
# Batch 937: fraud count = 0, non-fraud count = 112
# Batch 938: accuracy = 0.7679, true positive rate = 0.0000, false positives rate = 26.0000, true negative rate = 86.0000, false negative rate = 0.0000
# Batch 938: fraud count = 0, non-fraud count = 112
# Batch 939: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 939: fraud count = 0, non-fraud count = 112
# Batch 940: accuracy = 0.8750, true positive rate = 0.0000, false positives rate = 14.0000, true negative rate = 98.0000, false negative rate = 0.0000
# Batch 940: fraud count = 0, non-fraud count = 112
# Batch 941: accuracy = 0.9018, true positive rate = 0.0000, false positives rate = 11.0000, true negative rate = 101.0000, false negative rate = 0.0000
# Batch 941: fraud count = 0, non-fraud count = 112
# Batch 942: accuracy = 0.9196, true positive rate = 0.0000, false positives rate = 9.0000, true negative rate = 103.0000, false negative rate = 0.0000
# Batch 942: fraud count = 0, non-fraud count = 112
# Batch 943: accuracy = 0.8839, true positive rate = 0.0000, false positives rate = 13.0000, true negative rate = 99.0000, false negative rate = 0.0000
# Batch 943: fraud count = 0, non-fraud count = 112
# Batch 944: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 944: fraud count = 0, non-fraud count = 112
# Batch 945: accuracy = 0.9018, true positive rate = 0.0000, false positives rate = 11.0000, true negative rate = 101.0000, false negative rate = 0.0000
# Batch 945: fraud count = 0, non-fraud count = 112
# Batch 946: accuracy = 0.7946, true positive rate = 0.0000, false positives rate = 23.0000, true negative rate = 89.0000, false negative rate = 0.0000
# Batch 946: fraud count = 0, non-fraud count = 112
# Batch 947: accuracy = 0.8929, true positive rate = 0.0000, false positives rate = 12.0000, true negative rate = 100.0000, false negative rate = 0.0000
# Batch 947: fraud count = 0, non-fraud count = 112
# Batch 948: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 948: fraud count = 0, non-fraud count = 112
# Batch 949: accuracy = 0.9107, true positive rate = 0.0000, false positives rate = 10.0000, true negative rate = 102.0000, false negative rate = 0.0000
# Batch 949: fraud count = 0, non-fraud count = 112
# Batch 950: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 950: fraud count = 0, non-fraud count = 112
# Batch 951: accuracy = 0.8929, true positive rate = 0.0000, false positives rate = 12.0000, true negative rate = 100.0000, false negative rate = 0.0000
# Batch 951: fraud count = 0, non-fraud count = 112
# Batch 952: accuracy = 0.8571, true positive rate = 0.0000, false positives rate = 16.0000, true negative rate = 96.0000, false negative rate = 0.0000
# Batch 952: fraud count = 0, non-fraud count = 112
# Batch 953: accuracy = 0.7054, true positive rate = 0.0000, false positives rate = 33.0000, true negative rate = 79.0000, false negative rate = 0.0000
# Batch 953: fraud count = 0, non-fraud count = 112
# Batch 954: accuracy = 0.9286, true positive rate = 0.0000, false positives rate = 8.0000, true negative rate = 104.0000, false negative rate = 0.0000
# Batch 954: fraud count = 0, non-fraud count = 112
# Batch 955: accuracy = 0.7768, true positive rate = 0.0000, false positives rate = 25.0000, true negative rate = 87.0000, false negative rate = 0.0000
# Batch 955: fraud count = 0, non-fraud count = 112
# Batch 956: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 956: fraud count = 0, non-fraud count = 112
# Batch 957: accuracy = 0.9107, true positive rate = 0.0000, false positives rate = 10.0000, true negative rate = 102.0000, false negative rate = 0.0000
# Batch 957: fraud count = 0, non-fraud count = 112
# Batch 958: accuracy = 0.6875, true positive rate = 0.0000, false positives rate = 35.0000, true negative rate = 77.0000, false negative rate = 0.0000
# Batch 958: fraud count = 0, non-fraud count = 112
# Batch 959: accuracy = 0.5982, true positive rate = 0.0000, false positives rate = 45.0000, true negative rate = 67.0000, false negative rate = 0.0000
# Batch 959: fraud count = 0, non-fraud count = 112
# Batch 960: accuracy = 0.7768, true positive rate = 0.0000, false positives rate = 25.0000, true negative rate = 87.0000, false negative rate = 0.0000
# Batch 960: fraud count = 0, non-fraud count = 112
# Batch 961: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 961: fraud count = 0, non-fraud count = 112
# Batch 962: accuracy = 0.9018, true positive rate = 0.0000, false positives rate = 11.0000, true negative rate = 101.0000, false negative rate = 0.0000
# Batch 962: fraud count = 0, non-fraud count = 112
# Batch 963: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 963: fraud count = 0, non-fraud count = 112
# Batch 964: accuracy = 0.8571, true positive rate = 0.0000, false positives rate = 16.0000, true negative rate = 96.0000, false negative rate = 0.0000
# Batch 964: fraud count = 0, non-fraud count = 112
# Batch 965: accuracy = 0.8929, true positive rate = 0.0000, false positives rate = 12.0000, true negative rate = 100.0000, false negative rate = 0.0000
# Batch 965: fraud count = 0, non-fraud count = 112
# Batch 966: accuracy = 0.8304, true positive rate = 0.0000, false positives rate = 19.0000, true negative rate = 93.0000, false negative rate = 0.0000
# Batch 966: fraud count = 0, non-fraud count = 112
# Batch 967: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 967: fraud count = 0, non-fraud count = 112
# Batch 968: accuracy = 0.8571, true positive rate = 0.0000, false positives rate = 16.0000, true negative rate = 96.0000, false negative rate = 0.0000
# Batch 968: fraud count = 0, non-fraud count = 112
# Batch 969: accuracy = 1.0000, true positive rate = 0.0000, false positives rate = 0.0000, true negative rate = 112.0000, false negative rate = 0.0000
# Batch 969: fraud count = 0, non-fraud count = 112
# Batch 970: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 970: fraud count = 0, non-fraud count = 112
# Batch 971: accuracy = 0.8304, true positive rate = 0.0000, false positives rate = 19.0000, true negative rate = 93.0000, false negative rate = 0.0000
# Batch 971: fraud count = 0, non-fraud count = 112
# Batch 972: accuracy = 0.8929, true positive rate = 0.0000, false positives rate = 12.0000, true negative rate = 100.0000, false negative rate = 0.0000
# Batch 972: fraud count = 0, non-fraud count = 112
# Batch 973: accuracy = 0.9107, true positive rate = 0.0000, false positives rate = 10.0000, true negative rate = 102.0000, false negative rate = 0.0000
# Batch 973: fraud count = 0, non-fraud count = 112
# Batch 974: accuracy = 0.9911, true positive rate = 0.0000, false positives rate = 1.0000, true negative rate = 111.0000, false negative rate = 0.0000
# Batch 974: fraud count = 0, non-fraud count = 112
# Batch 975: accuracy = 0.8482, true positive rate = 0.0000, false positives rate = 17.0000, true negative rate = 95.0000, false negative rate = 0.0000
# Batch 975: fraud count = 0, non-fraud count = 112
# Batch 976: accuracy = 0.9196, true positive rate = 0.0000, false positives rate = 9.0000, true negative rate = 103.0000, false negative rate = 0.0000
# Batch 976: fraud count = 0, non-fraud count = 112
# Batch 977: accuracy = 0.8750, true positive rate = 0.0000, false positives rate = 14.0000, true negative rate = 98.0000, false negative rate = 0.0000
# Batch 977: fraud count = 0, non-fraud count = 112
# Batch 978: accuracy = 0.9732, true positive rate = 0.0000, false positives rate = 3.0000, true negative rate = 109.0000, false negative rate = 0.0000
# Batch 978: fraud count = 0, non-fraud count = 112
# Batch 979: accuracy = 0.8036, true positive rate = 0.0000, false positives rate = 22.0000, true negative rate = 90.0000, false negative rate = 0.0000
# Batch 979: fraud count = 0, non-fraud count = 112
# Batch 980: accuracy = 0.9375, true positive rate = 3.0000, false positives rate = 7.0000, true negative rate = 102.0000, false negative rate = 0.0000
# Batch 980: fraud count = 3, non-fraud count = 109
# Batch 981: accuracy = 0.9554, true positive rate = 0.0000, false positives rate = 5.0000, true negative rate = 107.0000, false negative rate = 0.0000
# Batch 981: fraud count = 0, non-fraud count = 112
# Batch 982: accuracy = 0.9286, true positive rate = 0.0000, false positives rate = 8.0000, true negative rate = 104.0000, false negative rate = 0.0000
# Batch 982: fraud count = 0, non-fraud count = 112
# Batch 983: accuracy = 0.9643, true positive rate = 0.0000, false positives rate = 4.0000, true negative rate = 108.0000, false negative rate = 0.0000
# Batch 983: fraud count = 0, non-fraud count = 112
# Batch 984: accuracy = 0.8214, true positive rate = 0.0000, false positives rate = 20.0000, true negative rate = 92.0000, false negative rate = 0.0000
# Batch 984: fraud count = 0, non-fraud count = 112
# Batch 985: accuracy = 0.9464, true positive rate = 0.0000, false positives rate = 6.0000, true negative rate = 106.0000, false negative rate = 0.0000
# Batch 985: fraud count = 0, non-fraud count = 112
# Batch 986: accuracy = 0.7589, true positive rate = 0.0000, false positives rate = 27.0000, true negative rate = 85.0000, false negative rate = 0.0000
# Batch 986: fraud count = 0, non-fraud count = 112
# Batch 987: accuracy = 0.8482, true positive rate = 0.0000, false positives rate = 17.0000, true negative rate = 95.0000, false negative rate = 0.0000
# Batch 987: fraud count = 0, non-fraud count = 112
# Batch 988: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 988: fraud count = 0, non-fraud count = 112
# Batch 989: accuracy = 0.8482, true positive rate = 0.0000, false positives rate = 17.0000, true negative rate = 95.0000, false negative rate = 0.0000
# Batch 989: fraud count = 0, non-fraud count = 112
# Batch 990: accuracy = 0.6696, true positive rate = 0.0000, false positives rate = 37.0000, true negative rate = 75.0000, false negative rate = 0.0000
# Batch 990: fraud count = 0, non-fraud count = 112
# Batch 991: accuracy = 0.9107, true positive rate = 0.0000, false positives rate = 10.0000, true negative rate = 102.0000, false negative rate = 0.0000
# Batch 991: fraud count = 0, non-fraud count = 112
# Batch 992: accuracy = 0.8839, true positive rate = 0.0000, false positives rate = 13.0000, true negative rate = 99.0000, false negative rate = 0.0000
# Batch 992: fraud count = 0, non-fraud count = 112
# Batch 993: accuracy = 0.9286, true positive rate = 0.0000, false positives rate = 8.0000, true negative rate = 104.0000, false negative rate = 0.0000
# Batch 993: fraud count = 0, non-fraud count = 112
# Batch 994: accuracy = 0.9375, true positive rate = 0.0000, false positives rate = 7.0000, true negative rate = 105.0000, false negative rate = 0.0000
# Batch 994: fraud count = 0, non-fraud count = 112
# Batch 995: accuracy = 0.8393, true positive rate = 0.0000, false positives rate = 18.0000, true negative rate = 94.0000, false negative rate = 0.0000
# Batch 995: fraud count = 0, non-fraud count = 112
# Batch 996: accuracy = 0.7768, true positive rate = 0.0000, false positives rate = 25.0000, true negative rate = 87.0000, false negative rate = 0.0000
# Batch 996: fraud count = 0, non-fraud count = 112
# Batch 997: accuracy = 0.7500, true positive rate = 0.0000, false positives rate = 28.0000, true negative rate = 84.0000, false negative rate = 0.0000
# Batch 997: fraud count = 0, non-fraud count = 112
# Batch 998: accuracy = 0.8482, true positive rate = 0.0000, false positives rate = 17.0000, true negative rate = 95.0000, false negative rate = 0.0000
# Batch 998: fraud count = 0, non-fraud count = 112
# Batch 999: accuracy = 0.7321, true positive rate = 0.0000, false positives rate = 30.0000, true negative rate = 82.0000, false negative rate = 0.0000
# Batch 999: fraud count = 0, non-fraud count = 112
# Batch 1000: accuracy = 0.7589, true positive rate = 0.0000, false positives rate = 27.0000, true negative rate = 85.0000, false negative rate = 0.0000
# Batch 1000: fraud count = 0, non-fraud count = 112
# Average accuracy on test data: 0.9586
# The number of transactions processed per second is:  45398.53752326041
# The total number of false positives from the set is:  4575
# The total number of false negatives from the set is:  63
# The total number of true positives from the set is:  150
# The total number of true negatives from the set is:  107212
# The precision score from the set is:  0.031746031746031744
# The recall score from the set is:  0.704225352112676
# The f1 score from the set is:  0.060753341433778855
# The false positive rate is:  0.04092604685696906
# The false negative rate is:  0.29577464788732394
# The actual number of non-fraud in this set is:  111787
# The actual number of fraud in this set is:  213
